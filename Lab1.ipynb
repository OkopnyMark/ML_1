# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
# Будем анализировать данные только на обучающей выборке
data = pd.read_csv('C:\\Users\\Mark\\data.csv', sep=",")

# %%
# Первые 5 строк датасета
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
# Размер датасета - 5000 строк, 6 колонок
data.shape
# Out:
# (5000, 6)

# %%
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
# Out:
# Всего строк: 5000

# %%
# Список колонок
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
# Список колонок с типами данных
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
# Проверим наличие пустых значений
# Цикл по колонкам датасета
for col in data.columns:
    # Количество пустых значений - все значения заполнены
    temp_null_count = data[data[col].isnull()].shape[0]
    print('{} - {}'.format(col, temp_null_count))
# Out:
# Rank - 0
# Grade - 0
# Channel name - 0
# Video Uploads - 0
# Subscribers - 0
# Video views - 0

# %%
# Основные статистические характеристки набора данных
data.describe()
# Out:
#         Video views
# count  5.000000e+03
# mean   1.071449e+09
# std    2.003844e+09
# min    7.500000e+01
# 25%    1.862329e+08
# 50%    4.820548e+08
# 75%    1.124368e+09
# max    4.754884e+10

# %%
# Определим уникальные значения для признака Rank
data['Rank'].unique()
# Out:
# array(['1st', '2nd', '3rd', ..., '4,998th', '4,999th', '5,000th'],
#       dtype=object)

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(ax=ax, x='Video Uploads', y='Subscribers', data=data)

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.distplot(data['Video views'])
# Out:
# C:\Users\Mark\Python\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(data)

# %%
#sns.jointplot(x='Video Uploads', y='Video views', data=data)

# %%
sns.boxplot(x=data['Video views'])

# %%
# По вертикали
sns.boxplot(y=data['Video views'])

# %%
sns.violinplot(x=data['Video views'])

# %%
fig, ax = plt.subplots(2, 1, figsize=(10,10))
sns.violinplot(ax=ax[0], x=data['Video views'])
sns.distplot(data['Subscribers'], ax=ax[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-8ee7c65cac3f> in <module>
#       1 fig, ax = plt.subplots(2, 1, figsize=(10,10))
#       2 sns.violinplot(ax=ax[0], x=data['Video views'])
# ----> 3 sns.distplot(data['Subscribers'], ax=ax[1])
#
# C:\Users\Mark\Python\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     196             line, = ax.plot(0, a.mean())
#     197         else:
# --> 198             line, = ax.plot(a.mean(), 0)
#     199         color = line.get_color()
#     200         line.remove()
#
# C:\Users\Mark\Python\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      85             ret = ret.dtype.type(ret / rcount)
#      86     else:
# ---> 87         ret = ret / rcount
#      88
# ...

# %%
data.corr()
# Out:
#              Video views
# Video views          1.0

# %%
data.corr(method='pearson')
# Out:
#              Video views
# Video views          1.0
